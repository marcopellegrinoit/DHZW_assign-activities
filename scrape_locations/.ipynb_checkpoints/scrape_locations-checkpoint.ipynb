# %% [markdown]
# # Scrape venues

# %%
import requests
import pandas as pd

# %%
# Define region
sw_long = 52.022926
sw_lat = 4.231183

ne_long = 52.062310
ne_lat = 4.313249

# define n cells per lat/long
n_cells = 2

# %%
# Read my foursquare api key
with open('../keys/foursquare_key.txt', 'r') as file:
    api_key = file.read().replace('\n', '')

# %%
URL = 'https://api.foursquare.com/v3/places/search?categories={}&ne={}&sw={}&limit=50'
headers = {
    "accept": "application/json",
    "Authorization": api_key
}

# %%
def read_foursquare_codes(path):
    df = pd.read_excel(path) # can also index sheet by name or fetch all sheets
    df = df[df['Included']=='y']
    codes = df['Code'].tolist()
    
    string_ints = [str(int) for int in codes]
    str_of_ints = ",".join(string_ints)
    
    return(str_of_ints)

# %%
path = 'codes_categories_foursquare/education_codes.xlsx'
categories = read_foursquare_codes(path)
categories
# Out:
# '12010,12014,12016,12022,12025,12032,12036,12039,12044,12045,12049,12050,12058,12059,12060,12061,12062,12063'

# %%
coordinates = []
delta_x = (ne_long - sw_long)/n_cells
delta_y = (ne_lat - sw_lat)/n_cells

venues = []
limit_50_reached = False

counter = 0
for y in range(n_cells):
    if (limit_50_reached == False):
        for x in range(n_cells):
            if (limit_50_reached == False):
                counter += 1
                sw_x = sw_long + x*delta_x
                sw_y = sw_lat + y*delta_y
                ne_x = sw_long + (x+1)*delta_x
                ne_y = sw_lat + (y+1)*delta_y

                north_east = str(ne_x) + ',' + str(ne_y)
                south_west = str(sw_x) + ',' + str(sw_y) 

                url = URL.format(categories, north_east, south_west)

                response = requests.get(url, headers=headers)

                data = response.json()['results']

                if (len(data) > 0):
                    if (len(data)==50):
                        print('Limit of 50 results reached! Make grids cells smaller.')
                        limit_50_reached = True
                        break
                    else:
                        venues = venues + data

                print('Proportion scraped:', round(counter/(n_cells**2), 2)*100, '%')
print('done')
# Out:
# Proportion scraped: 25.0 %
# Proportion scraped: 50.0 %
# Proportion scraped: 75.0 %
# Proportion scraped: 100.0 %
# done

# %%
df = pd.json_normalize(venues,
                       max_level=2,
                       record_path=['categories'],
                       meta=['fsq_id',
                             'name',
                             ['geocodes', 'main', 'latitude'],
                             ['geocodes', 'main', 'longitude'],
                             ['location', 'address'],
                             ['location', 'postcode']],
                       errors='ignore',
                       record_prefix='categories-'
                      )
df = df.drop(columns=['categories-icon.prefix', 'categories-icon.suffix', 'categories-id'])

# Rename columns
df = df.rename(columns={'location.postcode': 'PC6'})
df['PC6'] = df['PC6'].str.replace(" ", "")

df = df.rename(columns={'geocodes.main.latitude': 'latitude'})
df = df.rename(columns={'geocodes.main.longitude': 'longitude'})
df = df.rename(columns={'location.address': 'address'})
df = df.rename(columns={'categories-name': 'category'})

# Remove duplicates that might arise from the grid search
df = df.drop_duplicates()
df.to_csv('data/schools/schools_scraped.csv',
          index=False)

# %% [markdown]
# # Filter venues in DHZW

# %%
import geopandas
from shapely.geometry import Point

# %%
# Import polygon extent
df_DHZW = geopandas.read_file("DHZW_merged/DHZW_neighbs_shapefi_Project.shp")
# Convert the polygon CRS to the one of Foursquare
df_DHZW = df_DHZW.to_crs("EPSG:4326")

# Add a column to flag the venues in the area
df['withinQ'] = ""

withinQlist = []
for lon,lat in zip(df.longitude, df.latitude):
    pt = Point(lon, lat)
    withinQ = pt.within(df_DHZW['geometry'].values[0])
    withinQlist.append(withinQ)

# update values in the that column, values: True/False
df['withinQ'] = withinQlist
result_df = df[df.withinQ==True]
result_df = result_df.drop(columns=['withinQ'])

# %% [markdown]
# ## Plot venues

# %%
ax1 = df_DHZW.plot(color='pink')
ax1.scatter(result_df.longitude, result_df.latitude, s=50, color='green')

# %%
result_df
# Out:
#                      category                    fsq_id  \
# 0                 High School  4d8d485e5091a1cd1a257501
# 1           Elementary School  55f6672e498e0e311e3147a1
# 2                  Law School  4f38b56ae4b0cc4ce4cfb3ce
# 4   College Academic Building  4d2363da16cfb60cce517161
# 5           Elementary School  5650e23a5aff44a2f7ea8c9c
# 6           Elementary School  f7f222c20fdd43b895f6917f
# 7           Elementary School  97fced1f0718427275b3a8ea
# 8           Elementary School  2f232cb92bbd4c734e2571e6
# 9           Elementary School  125b16cd04b34e7068284271
# 10          Elementary School  415014f6a3734ee1098a936b
# 11          Elementary School  4f02e3a015254dbee2129e21
# 12          Elementary School  515112fbf0f843f7360b427f
# 14             Medical School  4f0aef120039c4c8db88e4b6
# 18             Medical School  55681d1e498e203b55de7cc8
# 19                High School  4e5bb32a814db47c3030601f
# 20          Elementary School  4dc8d9851838e695fbdbf1a3
# 21             Medical School  4f880148e4b057e27f23a685
# 24          College Classroom  4d9f47ea8ef3a1435ef48f10
# 25                High School  4d2b0ce3ebacb1f7ad9f0850
# 26               Trade School  4cef9f9728abb60cba7ac309
# 27          Elementary School  592c12506a595012a64e4d71
# 28          Elementary School  504b189fe4b03c3db118c05f
# 29          Elementary School  4dd39815d1643acaa1e42ce2
# 30  College Academic Building  4fd059a9e4b0f962e385f1c7
# 35          Elementary School  e4dc347689d742af8439aa05
# 36          Elementary School  5d33d79001364370d5fa63da
# 37          Elementary School  4cf8ba5bf61542cfc8cb02ed
# 38          Elementary School  d30ba1050a2a40d311711b60
# 39          Elementary School  c9dbf4d9b89b4b7d22392a39
# 53               Trade School  52876027498e87aa6781dd88
# 54          Elementary School  4df760dcae60f0da88390edd
# 55          Elementary School  51874f68498ef49c92e3827f
# 56               Trade School  4da82c9e43a12d0c264a0a45
# 57          Elementary School  4b8ea40cf964a520d12d33e3
# 59                 Law School  4d7f7e85b25d6dcb2e39ce42
# 61          Elementary School  551931b5498eafeae3d016a2
# 62          Elementary School  4e492492a809fb2fa40d6fbc
# 5                  Laagveen 22  2544RZ
# 6                 Haardstede 1  2543VS
# 7            Beresteinlaan 267  2542JG
# 8                 Woonstede 96  2543VR
# 9             Ambachtsgaarde 5  2542ED
# 10            Ambachtsgaarde 1  2542ED
# 11                 Eindstede 2  2543BH
# 12        Melis Stokelaan 1185  2541GA
# 14            Dedemsvaartweg 1  2545AP
# 18                         NaN     NaN
# 19                  Tinwerf 10  2544ED
# 20              Marterrade 312  2544ME
# 21                         NaN     NaN
# 24       Zuidlarenstraat 6 -10  2545VX
# 25               Meppelweg 339     NaN
# 26                 Zinkwerf 85  2544EC
# 27            Zweeloostraat 61  2545VC
# 28                  Edamstraat     NaN
# 29     Maarsbergenstraat 169/C  2546SP
# 30                         NaN     NaN
# 35          Baambruggestraat 2  2546SK
# 36                Edamstraat 2  2547VR
# 37            Zweeloostraat 61  2545VC
# 38               Norgstraat 12  2545TV
# 39    Oosterhesselenstraat 586  2545SL
# 53   Roemer Visscherstraat 106  2533VG
# 54               Erasmusweg 68  2532CR
# 55  Pieter Langendijkstraat 81  2533TG
# 56           Beatrijsstraat 12  2531XE
# 57        Rederijkerstraat 120  2531VP
# 59               Ulenpasstraat     NaN
# 61                         NaN     NaN
# 62           Tinaarlostraat 78  2545RD
# 63   Roemer Visscherstraat 106  2533VG
# 64        Rederijkerstraat 120  2531VP
# 65       Van Ruysbroekstraat 1  2531TG
# 66            Steenwijklaan 10  2541RL
# 67             Twickelstraat 5  2531PW

# %% [markdown]
# ## PC6 reconstruction

# %%
# Read geometry of PC6 in the area
df_PC6 = geopandas.read_file("DHZW_PC6_shapefile/DHZW_PC6_shapefile.shp")

# Apply the Foursquare CRS to the area
df_PC6_crs = df_PC6_crs.to_crs("EPSG:4326")

# %%
# Calculate geometry point for the venues from their longitude and latitude
df = geopandas.GeoDataFrame(result_df, geometry=geopandas.points_from_xy(result_df.longitude, result_df.latitude))

# Remove the PC6 from Foursquare, to be overridden
df = df.drop(columns=['PC6'])
# Out:
# C:\Users\6997619\Anaconda3\envs\dhzw_env\lib\site-packages\geopandas\array.py:275: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   return GeometryArray(vectorized.points_from_xy(x, y, z), crs=crs)

# %%
# Spatial join
df = geopandas.sjoin(df, df_PC6_crs)
# Out:
# C:\Users\6997619\AppData\Local\Temp\ipykernel_10572\2707079593.py:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   df = geopandas.sjoin(df, df_PC6_crs)

# %%
df = df.drop(columns=['index_right', 'geometry'])
df.to_csv('data/schools.csv', index=False)

# %%
df
# Out:
#                      category                    fsq_id  \
# 0                 High School  4d8d485e5091a1cd1a257501
# 6           Elementary School  f7f222c20fdd43b895f6917f
# 1           Elementary School  55f6672e498e0e311e3147a1
# 2                  Law School  4f38b56ae4b0cc4ce4cfb3ce
# 4   College Academic Building  4d2363da16cfb60cce517161
# 5           Elementary School  5650e23a5aff44a2f7ea8c9c
